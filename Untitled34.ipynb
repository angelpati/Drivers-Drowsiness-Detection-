# %% [markdown]
# <a href="https://colab.research.google.com/github/angelpati/Drivers-Drowsiness-Detection-/blob/main/Untitled34.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3114a967-f666-40e9-93df-75f156365294" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3114a967-f666-40e9-93df-75f156365294">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e455609c-02a6-478e-8f29-3e668dbdcbac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e455609c-02a6-478e-8f29-3e668dbdcbac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-321dd631-6409-4dfc-a59d-c594d28b578f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-321dd631-6409-4dfc-a59d-c594d28b578f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pip install opencv-python dlib imutils scipy playsound

# %%
# Install necessary libraries (for Google Colab)
# !pip install opencv-python dlib imutils scipy playsound

# ------------------------ IMPORTS ------------------------
import cv2
import dlib
import numpy as np
from imutils import face_utils
from scipy.spatial import distance
from playsound import playsound
import threading
import os

# ------------------------ ALERT SYSTEM ------------------------
def play_alert(sound_file):
    threading.Thread(target=playsound, args=(sound_file,), daemon=True).start()

# ------------------------ EAR + MAR CALCULATIONS ------------------------
def eye_aspect_ratio(eye):
    A = distance.euclidean(eye[1], eye[5])
    B = distance.euclidean(eye[2], eye[4])
    C = distance.euclidean(eye[0], eye[3])
    return (A + B) / (2.0 * C)

def mouth_aspect_ratio(mouth):
    A = distance.euclidean(mouth[13], mouth[19])
    B = distance.euclidean(mouth[14], mouth[18])
    C = distance.euclidean(mouth[15], mouth[17])
    D = distance.euclidean(mouth[12], mouth[16])
    return (A + B + C) / (3.0 * D)

# ------------------------ CONFIG ------------------------
EAR_THRESHOLD = 0.25
EAR_CONSEC_FRAMES = 20
MAR_THRESHOLD = 0.75
VIDEO_PATH = "WIN_20250526_23_00_09_Pro.mp4"  # Replace with your uploaded video path
LANDMARK_MODEL = "shape_predictor_68_face_landmarks (1).dat"
DROWSY_SOUND = "emergency-alarm-69780.mp3"
YAWN_SOUND = "emergency-alarm-69780.mp3"

# ------------------------ LOAD MODELS ------------------------
print("[INFO] Loading models...")
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor(LANDMARK_MODEL)

(lStart, lEnd) = face_utils.FACIAL_LANDMARKS_IDXS["left_eye"]
(rStart, rEnd) = face_utils.FACIAL_LANDMARKS_IDXS["right_eye"]
(mStart, mEnd) = face_utils.FACIAL_LANDMARKS_IDXS["mouth"]

# ------------------------ PROCESS VIDEO ------------------------
cap = cv2.VideoCapture(VIDEO_PATH)
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output_with_alerts.avi', fourcc, 20.0, (640, 480))

COUNTER = 0

print("[INFO] Processing video...")
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.resize(frame, (640, 480))
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    rects = detector(gray, 0)

    for rect in rects:
        shape = predictor(gray, rect)
        shape = face_utils.shape_to_np(shape)

        leftEye = shape[lStart:lEnd]
        rightEye = shape[rStart:rEnd]
        mouth = shape[mStart:mEnd]

        leftEAR = eye_aspect_ratio(leftEye)
        rightEAR = eye_aspect_ratio(rightEye)
        ear = (leftEAR + rightEAR) / 2.0
        mar = mouth_aspect_ratio(mouth)

        # Draw facial features
        cv2.drawContours(frame, [cv2.convexHull(leftEye)], -1, (0, 255, 0), 1)
        cv2.drawContours(frame, [cv2.convexHull(rightEye)], -1, (0, 255, 0), 1)
        cv2.drawContours(frame, [cv2.convexHull(mouth)], -1, (0, 0, 255), 1)

        # Drowsiness detection
        if ear < EAR_THRESHOLD:
            COUNTER += 1
            if COUNTER >= EAR_CONSEC_FRAMES:
                cv2.putText(frame, "DROWSINESS DETECTED!", (10, 30),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
                play_alert(DROWSY_SOUND)
        else:
            COUNTER = 0

        # Yawning detection
        if mar > MAR_THRESHOLD:
            cv2.putText(frame, "YAWNING DETECTED!", (10, 60),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 0, 0), 2)
            play_alert(YAWN_SOUND)

        # Display EAR & MAR
        cv2.putText(frame, f"EAR: {ear:.2f}", (500, 30),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 0), 2)
        cv2.putText(frame, f"MAR: {mar:.2f}", (500, 60),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 0), 2)

    # Save frame to output video
    out.write(frame)

# ------------------------ CLEANUP ------------------------
cap.release()
out.release()
cv2.destroyAllWindows()
print("[INFO] Output saved as 'output_with_alerts.avi'")
# Out:
# ...
# [INFO] Loading models...
# [INFO] Processing video...
# Exception in thread Thread-80 (<lambda>):
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/playsound.py", line 254, in <lambda>
#     playsound = lambda sound, block = True: _playsoundAnotherPython('/usr/bin/python3', sound, block, macOS = False)
#                                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/playsound.py", line 229, in _playsoundAnotherPython
#     t.join()
#   File "/usr/local/lib/python3.11/dist-packages/playsound.py", line 218, in join
#     raise self.exc
#   File "/usr/local/lib/python3.11/dist-packages/playsound.py", line 211, in run
# ...

# %%
from google.colab import files
files.download("output_with_alerts.avi")

# %%
import os
print("Output file exists:", os.path.exists("output_with_alerts.avi"))
# Out:
# Output file exists: True
